# %% [markdown]
# # Simulation

# %%
# %matplotlib notebook

import numpy as np
from probotics import Simulator, Roomba
from probotics.src.utils import load_yaml

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Corremos la simulación en el notebook

# %%
config = load_yaml("../configs/simulation.yaml")
# s = Simulator(**config).run((5,15),(12,22))
s = Simulator(**config).run((20,30),(5,15))
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
config = load_yaml("../configs/ros.yaml")
# s = Roomba(**config).run((0,10),(0,10))
s = Roomba(**config).run((-10,0),(-10,0))
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">
